# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"Car_sales.csv")

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.shape
# Out:
# (157, 16)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
data['Model'].unique()
# Out:
# array(['Integra', 'TL', 'CL', 'RL', 'A4', 'A6', 'A8', '323i', '328i',
#        '528i', 'Century', 'Regal', 'Park Avenue', 'LeSabre', 'DeVille',
#        'Seville', 'Eldorado', 'Catera', 'Escalade', 'Cavalier', 'Malibu',
#        'Lumina', 'Monte Carlo', 'Camaro', 'Corvette', 'Prizm', 'Metro',
#        'Impala', 'Sebring Coupe', 'Sebring Conv.', 'Concorde', 'Cirrus',
#        'LHS', 'Town & Country', '300M', 'Neon', 'Avenger', 'Stratus',
#        'Intrepid', 'Viper', 'Ram Pickup', 'Ram Wagon', 'Ram Van',
#        'Dakota', 'Durango', 'Caravan', 'Escort', 'Mustang', 'Contour',
#        'Taurus', 'Focus', 'Crown Victoria', 'Explorer', 'Windstar',
#        'Expedition', 'Ranger', 'F-Series', 'Civic', 'Accord', 'CR-V',
#        'Passport', 'Odyssey', 'Accent', 'Elantra', 'Sonata', 'I30',
#        'S-Type', 'Wrangler', 'Cherokee', 'Grand Cherokee', 'ES300',
#        'GS300', 'GS400', 'LS400', 'LX470', 'RX300', 'Continental',
# ...

# %%
data.nunique()
# Out:
# Manufacturer            30
# Model                  156
# Sales_in_thousands     157
# __year_resale_value    117
# Vehicle_type             2
# Price_in_thousands     152
# Engine_size             31
# Horsepower              66
# Wheelbase               88
# Width                   78
# Length                 127
# Curb_weight            147
# Fuel_capacity           55
# Fuel_efficiency         20
# Latest_Launch          130
# Power_perf_factor      154
# dtype: int64

# %%
data.count()
# Out:
# Manufacturer           157
# Model                  157
# Sales_in_thousands     157
# __year_resale_value    121
# Vehicle_type           157
# Price_in_thousands     155
# Engine_size            156
# Horsepower             156
# Wheelbase              156
# Width                  156
# Length                 156
# Curb_weight            155
# Fuel_capacity          156
# Fuel_efficiency        154
# Latest_Launch          157
# Power_perf_factor      155
# dtype: int64

# %%
data['Model'].value_counts()
# Out:
# Model
# Neon          2
# Integra       1
# Cutlass       1
# Sentra        1
# Altima        1
#              ..
# Windstar      1
# Expedition    1
# Ranger        1
# F-Series      1
# S80           1
# Name: count, Length: 156, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778

# %%
data['Model'].nunique()
# Out:
# 156

# %%
data.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Manufacturer           157
# Model                  157
# Sales_in_thousands     157
# __year_resale_value    121
# Vehicle_type           157
# Price_in_thousands     155
# Engine_size            156
# Horsepower             156
# Wheelbase              156
# Width                  156
# Length                 156
# Curb_weight            155
# Fuel_capacity          156
# Fuel_efficiency        154
# Latest_Launch          157
# Power_perf_factor      155
# dtype: int64

# %%
data.rename(columns = {'Model' : 'Model Series'})
# Out:
#     Manufacturer Model Series  Sales_in_thousands  __year_resale_value  \
# 0          Acura      Integra              16.919               16.360
# 1          Acura           TL              39.384               19.875
# 2          Acura           CL              14.114               18.225
# 3          Acura           RL               8.588               29.725
# 4           Audi           A4              20.397               22.255
# ..           ...          ...                 ...                  ...
# 152        Volvo          V40               3.545                  NaN
# 153        Volvo          S70              15.245                  NaN
# 154        Volvo          V70              17.531                  NaN
# 155        Volvo          C70               3.493                  NaN
# 156        Volvo          S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.rename(columns = {'Model' : 'Model Series' } ,inplace=True)

# %%
data.Price_in_thousands.mean()
# Out:
# 27.390754838709682

# %%
horse = data[data['Horsepower'] > 140]
horse.head(50)
# Out:
#    Manufacturer    Model Series  Sales_in_thousands  __year_resale_value  \
# 1         Acura              TL              39.384               19.875
# 2         Acura              CL              14.114               18.225
# 3         Acura              RL               8.588               29.725
# 4          Audi              A4              20.397               22.255
# 5          Audi              A6              18.780               23.555
# 6          Audi              A8               1.380               39.000
# 7           BMW            323i              19.747                  NaN
# 8           BMW            328i               9.231               28.675
# 9           BMW            528i              17.527               36.125
# 10        Buick         Century              91.561               12.475
# 11        Buick           Regal              39.350               13.740
# 12        Buick     Park Avenue              27.851               20.190
# ...

# %%
data[data['Manufacturer'].str.contains('BMW')].head()
# Out:
#   Manufacturer Model Series  Sales_in_thousands  __year_resale_value  \
# 7          BMW         323i              19.747                  NaN
# 8          BMW         328i               9.231               28.675
# 9          BMW         528i              17.527               36.125
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 7    Passenger               26.99          2.5       170.0      107.3   68.4
# 8    Passenger               33.40          2.8       193.0      107.3   68.5
# 9    Passenger               38.90          2.8       193.0      111.4   70.9
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 7   176.0        3.179           16.6             26.0     6/28/2011
# 8   176.0        3.197           16.6             24.0     1/29/2012
# 9   188.0        3.472           18.5             25.0      4/4/2011
#
#    Power_perf_factor
# 7          71.191207
# 8          81.877069
# 9          83.998724

# %%
data[(data['Manufacturer'] == "Audi") & (data['Vehicle_type'] == "Passenger")]
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 4         Audi    A4              20.397               22.255    Passenger
# 5         Audi    A6              18.780               23.555    Passenger
# 6         Audi    A8               1.380               39.000    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
# 6               62.00          4.2       310.0      113.0   74.0   198.2
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 4        2.998           16.4             27.0     10/8/2011
# 5        3.561           18.5             22.0      8/9/2011
# 6        3.902           23.7             21.0     2/27/2012
#
#    Power_perf_factor
# 4          62.777639
# 5          84.565105
# 6         134.656858

# %%
data_mean = data.groupby('Price_in_thousands').min()
data_mean.head(12)
# Out:
#                    Manufacturer    Model  Sales_in_thousands  \
# Price_in_thousands
# 9.235                 Chevrolet    Metro              21.855
# 9.699                   Hyundai   Accent              41.184
# 10.685                   Saturn       SL              80.620
# 11.528                   Toyota   Tacoma              84.087
# 11.799                  Hyundai  Elantra              66.692
# 12.050                     Ford   Ranger             220.650
# 12.070                     Ford   Escort              70.227
# 12.315                     Ford    Focus             175.670
# 12.535                   Saturn       SC              24.546
# 12.640                    Dodge     Neon              32.734
# 12.885                    Honda    Civic             199.685
# 13.108                   Toyota  Corolla             142.535
#
#                     __year_resale_value Vehicle_type  Engine_size  Horsepower  \
# Price_in_thousands
# ...

# %%
data_max = data.groupby('Price_in_thousands').max()
data_max_sorted
# Out:
#                    Manufacturer           Model  Sales_in_thousands  \
# Price_in_thousands
# 85.500               Mercedes-B           CL500               0.954
# 82.600               Mercedes-B        SL-Class               3.311
# 74.970                  Porsche  Carrera Cabrio               1.866
# 71.020                  Porsche   Carrera Coupe               1.280
# 69.725                    Dodge           Viper               0.916
# ...                         ...             ...                 ...
# 11.799                  Hyundai         Elantra              66.692
# 11.528                   Toyota          Tacoma              84.087
# 10.685                   Saturn              SL              80.620
# 9.699                   Hyundai          Accent              41.184
# 9.235                 Chevrolet           Metro              21.855
#
#                     __year_resale_value Vehicle_type  Engine_size  Horsepower  \
# Price_in_thousands
# ...

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
data['Latest_Launch'] = pd.to_datetime(data['Latest_Launch'])
data['Latest_Launch']
# Out:
# 0     2012-02-02
# 1     2011-06-03
# 2     2012-01-04
# 3     2011-03-10
# 4     2011-10-08
#          ...
# 152   2011-09-21
# 153   2012-11-24
# 154   2011-06-25
# 155   2011-04-26
# 156   2011-11-14
# Name: Latest_Launch, Length: 157, dtype: datetime64[ns]

# %%
data.dtypes
# Out:
# Manufacturer                   object
# Model                          object
# Sales_in_thousands            float64
# __year_resale_value           float64
# Vehicle_type                   object
# Price_in_thousands            float64
# Engine_size                   float64
# Horsepower                    float64
# Wheelbase                     float64
# Width                         float64
# Length                        float64
# Curb_weight                   float64
# Fuel_capacity                 float64
# Fuel_efficiency               float64
# Latest_Launch          datetime64[ns]
# Power_perf_factor             float64
# dtype: object

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data['Year'] = data.Latest_Launch.dt.year

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.insert(15 ,'month' , data.Latest_Launch.dt.month)

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
average_sales_per_year = data.groupby('Year')['Sales_in_thousands'].mean()
print(average_sales_per_year)
# Out:
# Year
# 2008    27.609000
# 2009    50.317500
# 2011    47.055759
# 2012    59.667320
# Name: Sales_in_thousands, dtype: float64

# %%
data.plot() 
plt.savefig('lineplot.png')
